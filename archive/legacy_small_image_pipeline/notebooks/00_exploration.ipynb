# %% [markdown]
# # Exploración inicial
#
# Notebook reservado para pruebas pequeñas de lectura, patching y visualización. No usar para descargar datasets, WSI ni pesos grandes.

# %%
from src.config.paths import ensure_directories

ensure_directories()
